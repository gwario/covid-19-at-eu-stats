# %%
import pandas
import lib.csse_covid_19_dataset.data_processing as data_processing
import data

output_dir = data.data_dir

output_filename = data.hopkins_data_filename


infected_column_name = 'Infected (confirmed)'
deceased_column_name = 'Deceased'
recovered_column_name = 'Recovered'

# get confirmed data
df_csse_covid_19_dataset_confirmed = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv',
                                                     infer_datetime_format=True, parse_dates=True)
df_confirmed_prep = data_processing.getCasesPerDayAndCountry(df_csse_covid_19_dataset_confirmed)
# add toplevel column header for confirmed
df_confirmed_prep.columns = pandas.MultiIndex.from_tuples(map(lambda x: (infected_column_name, x[0], x[1]), df_confirmed_prep.columns))

# get deaths data
df_csse_covid_19_dataset_deaths = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv',
                                           infer_datetime_format=True, parse_dates=True)
df_deaths_prep = data_processing.getCasesPerDayAndCountry(df_csse_covid_19_dataset_deaths)
# add toplevel column header for deceased
df_deaths_prep.columns = pandas.MultiIndex.from_tuples(map(lambda x: (deceased_column_name, x[0], x[1]), df_deaths_prep.columns))

# get recovered data
df_csse_covid_19_dataset_recovered = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv',
                                           infer_datetime_format=True, parse_dates=True)
df_recovered_prep = data_processing.getCasesPerDayAndCountry(df_csse_covid_19_dataset_recovered)
# add toplevel column header for recovered
df_recovered_prep.columns = pandas.MultiIndex.from_tuples(map(lambda x: (recovered_column_name, x[0], x[1]), df_recovered_prep.columns))

# get everything into one dataframe
df_prep = pandas.concat([df_confirmed_prep, df_deaths_prep, df_recovered_prep], axis=1)

# Remove sum up provice data
# Flip indices
df_prep.columns = df_prep.columns.swaplevel(0, 1)
df_prep.columns = df_prep.columns.swaplevel(1, 2)
#print(df_prep.columns.values)
# e.g. ('US', 'Ulster County, NY', 'Infected (confirmed)')
# Remove provinces and sum up values from provinces
data_processing.dropProvinceIndex(df_prep)
df_prep = df_prep.groupby(level=[0, 1], axis=1).sum()
#print(df_prep.columns)

print("Loaded covid-19 data:")
print(df_prep.columns.values)
print(df_prep.index.values)

df_prep.to_csv(output_dir+output_filename)
# Out:
# Loaded covid-19 data:
# [('Afghanistan', 'Deceased') ('Afghanistan', 'Infected (confirmed)')
#  ('Afghanistan', 'Recovered') ('Albania', 'Deceased')
#  ('Albania', 'Infected (confirmed)') ('Albania', 'Recovered')
#  ('Algeria', 'Deceased') ('Algeria', 'Infected (confirmed)')
#  ('Algeria', 'Recovered') ('Andorra', 'Deceased')
#  ('Andorra', 'Infected (confirmed)') ('Andorra', 'Recovered')
#  ('Antigua and Barbuda', 'Deceased')
#  ('Antigua and Barbuda', 'Infected (confirmed)')
#  ('Antigua and Barbuda', 'Recovered') ('Argentina', 'Deceased')
#  ('Argentina', 'Infected (confirmed)') ('Argentina', 'Recovered')
#  ('Armenia', 'Deceased') ('Armenia', 'Infected (confirmed)')
#  ('Armenia', 'Recovered') ('Australia', 'Deceased')
#  ('Australia', 'Infected (confirmed)') ('Australia', 'Recovered')
#  ('Austria', 'Deceased') ('Austria', 'Infected (confirmed)')
#  ('Austria', 'Recovered') ('Azerbaijan', 'Deceased')
#  ('Azerbaijan', 'Infected (confirmed)') ('Azerbaijan', 'Recovered')
#  ('Bahamas, The', 'Deceased') ('Bahamas, The', 'Infected (confirmed)')
#  ('Bahamas, The', 'Recovered') ('Bahrain', 'Deceased')
#  ('Bahrain', 'Infected (confirmed)') ('Bahrain', 'Recovered')
#  ('Bangladesh', 'Deceased') ('Bangladesh', 'Infected (confirmed)')
#  ('Bangladesh', 'Recovered') ('Barbados', 'Deceased')
#  ('Barbados', 'Infected (confirmed)') ('Barbados', 'Recovered')
#  ('Belarus', 'Deceased') ('Belarus', 'Infected (confirmed)')
#  ('Belarus', 'Recovered') ('Belgium', 'Deceased')
#  ('Belgium', 'Infected (confirmed)') ('Belgium', 'Recovered')
#  ('Benin', 'Deceased') ('Benin', 'Infected (confirmed)')
#  ('Benin', 'Recovered') ('Bhutan', 'Deceased')
#  ('Bhutan', 'Infected (confirmed)') ('Bhutan', 'Recovered')
#  ('Bolivia', 'Deceased') ('Bolivia', 'Infected (confirmed)')
#  ('Bolivia', 'Recovered') ('Bosnia and Herzegovina', 'Deceased')
#  ('Bosnia and Herzegovina', 'Infected (confirmed)')
#  ('Bosnia and Herzegovina', 'Recovered') ('Brazil', 'Deceased')
#  ('Brazil', 'Infected (confirmed)') ('Brazil', 'Recovered')
#  ('Brunei', 'Deceased') ('Brunei', 'Infected (confirmed)')
#  ('Brunei', 'Recovered') ('Bulgaria', 'Deceased')
#  ('Bulgaria', 'Infected (confirmed)') ('Bulgaria', 'Recovered')
#  ('Burkina Faso', 'Deceased') ('Burkina Faso', 'Infected (confirmed)')
#  ('Burkina Faso', 'Recovered') ('Cambodia', 'Deceased')
#  ('Cambodia', 'Infected (confirmed)') ('Cambodia', 'Recovered')
#  ('Cameroon', 'Deceased') ('Cameroon', 'Infected (confirmed)')
#  ('Cameroon', 'Recovered') ('Canada', 'Deceased')
#  ('Canada', 'Infected (confirmed)') ('Canada', 'Recovered')
#  ('Central African Republic', 'Deceased')
#  ('Central African Republic', 'Infected (confirmed)')
#  ('Central African Republic', 'Recovered') ('Chad', 'Deceased')
#  ('Chad', 'Infected (confirmed)') ('Chad', 'Recovered')
#  ('Chile', 'Deceased') ('Chile', 'Infected (confirmed)')
#  ('Chile', 'Recovered') ('China', 'Deceased')
#  ('China', 'Infected (confirmed)') ('China', 'Recovered')
#  ('Colombia', 'Deceased') ('Colombia', 'Infected (confirmed)')
#  ('Colombia', 'Recovered') ('Congo (Brazzaville)', 'Deceased')
#  ('Congo (Brazzaville)', 'Infected (confirmed)')
#  ('Congo (Brazzaville)', 'Recovered') ('Congo (Kinshasa)', 'Deceased')
#  ('Congo (Kinshasa)', 'Infected (confirmed)')
#  ('Congo (Kinshasa)', 'Recovered') ('Costa Rica', 'Deceased')
#  ('Costa Rica', 'Infected (confirmed)') ('Costa Rica', 'Recovered')
#  ("Cote d'Ivoire", 'Deceased') ("Cote d'Ivoire", 'Infected (confirmed)')
#  ("Cote d'Ivoire", 'Recovered') ('Croatia', 'Deceased')
#  ('Croatia', 'Infected (confirmed)') ('Croatia', 'Recovered')
#  ('Cruise Ship', 'Deceased') ('Cruise Ship', 'Infected (confirmed)')
#  ('Cruise Ship', 'Recovered') ('Cuba', 'Deceased')
#  ('Cuba', 'Infected (confirmed)') ('Cuba', 'Recovered')
#  ('Cyprus', 'Deceased') ('Cyprus', 'Infected (confirmed)')
#  ('Cyprus', 'Recovered') ('Czechia', 'Deceased')
#  ('Czechia', 'Infected (confirmed)') ('Czechia', 'Recovered')
#  ('Denmark', 'Deceased') ('Denmark', 'Infected (confirmed)')
#  ('Denmark', 'Recovered') ('Djibouti', 'Deceased')
#  ('Djibouti', 'Infected (confirmed)') ('Djibouti', 'Recovered')
#  ('Dominican Republic', 'Deceased')
#  ('Dominican Republic', 'Infected (confirmed)')
#  ('Dominican Republic', 'Recovered') ('Ecuador', 'Deceased')
#  ('Ecuador', 'Infected (confirmed)') ('Ecuador', 'Recovered')
#  ('Egypt', 'Deceased') ('Egypt', 'Infected (confirmed)')
#  ('Egypt', 'Recovered') ('El Salvador', 'Deceased')
#  ('El Salvador', 'Infected (confirmed)') ('El Salvador', 'Recovered')
#  ('Equatorial Guinea', 'Deceased')
#  ('Equatorial Guinea', 'Infected (confirmed)')
#  ('Equatorial Guinea', 'Recovered') ('Estonia', 'Deceased')
#  ('Estonia', 'Infected (confirmed)') ('Estonia', 'Recovered')
#  ('Eswatini', 'Deceased') ('Eswatini', 'Infected (confirmed)')
#  ('Eswatini', 'Recovered') ('Ethiopia', 'Deceased')
#  ('Ethiopia', 'Infected (confirmed)') ('Ethiopia', 'Recovered')
#  ('Fiji', 'Deceased') ('Fiji', 'Infected (confirmed)')
#  ('Fiji', 'Recovered') ('Finland', 'Deceased')
#  ('Finland', 'Infected (confirmed)') ('Finland', 'Recovered')
#  ('France', 'Deceased') ('France', 'Infected (confirmed)')
#  ('France', 'Recovered') ('Gabon', 'Deceased')
#  ('Gabon', 'Infected (confirmed)') ('Gabon', 'Recovered')
#  ('Gambia, The', 'Deceased') ('Gambia, The', 'Infected (confirmed)')
#  ('Gambia, The', 'Recovered') ('Georgia', 'Deceased')
#  ('Georgia', 'Infected (confirmed)') ('Georgia', 'Recovered')
#  ('Germany', 'Deceased') ('Germany', 'Infected (confirmed)')
#  ('Germany', 'Recovered') ('Ghana', 'Deceased')
#  ('Ghana', 'Infected (confirmed)') ('Ghana', 'Recovered')
#  ('Greece', 'Deceased') ('Greece', 'Infected (confirmed)')
#  ('Greece', 'Recovered') ('Guatemala', 'Deceased')
#  ('Guatemala', 'Infected (confirmed)') ('Guatemala', 'Recovered')
#  ('Guinea', 'Deceased') ('Guinea', 'Infected (confirmed)')
#  ('Guinea', 'Recovered') ('Guyana', 'Deceased')
#  ('Guyana', 'Infected (confirmed)') ('Guyana', 'Recovered')
#  ('Holy See', 'Deceased') ('Holy See', 'Infected (confirmed)')
#  ('Holy See', 'Recovered') ('Honduras', 'Deceased')
#  ('Honduras', 'Infected (confirmed)') ('Honduras', 'Recovered')
#  ('Hungary', 'Deceased') ('Hungary', 'Infected (confirmed)')
#  ('Hungary', 'Recovered') ('Iceland', 'Deceased')
#  ('Iceland', 'Infected (confirmed)') ('Iceland', 'Recovered')
#  ('India', 'Deceased') ('India', 'Infected (confirmed)')
#  ('India', 'Recovered') ('Indonesia', 'Deceased')
#  ('Indonesia', 'Infected (confirmed)') ('Indonesia', 'Recovered')
#  ('Iran', 'Deceased') ('Iran', 'Infected (confirmed)')
#  ('Iran', 'Recovered') ('Iraq', 'Deceased')
#  ('Iraq', 'Infected (confirmed)') ('Iraq', 'Recovered')
#  ('Ireland', 'Deceased') ('Ireland', 'Infected (confirmed)')
#  ('Ireland', 'Recovered') ('Israel', 'Deceased')
#  ('Israel', 'Infected (confirmed)') ('Israel', 'Recovered')
#  ('Italy', 'Deceased') ('Italy', 'Infected (confirmed)')
#  ('Italy', 'Recovered') ('Jamaica', 'Deceased')
#  ('Jamaica', 'Infected (confirmed)') ('Jamaica', 'Recovered')
#  ('Japan', 'Deceased') ('Japan', 'Infected (confirmed)')
#  ('Japan', 'Recovered') ('Jordan', 'Deceased')
#  ('Jordan', 'Infected (confirmed)') ('Jordan', 'Recovered')
#  ('Kazakhstan', 'Deceased') ('Kazakhstan', 'Infected (confirmed)')
#  ('Kazakhstan', 'Recovered') ('Kenya', 'Deceased')
#  ('Kenya', 'Infected (confirmed)') ('Kenya', 'Recovered')
#  ('Korea, South', 'Deceased') ('Korea, South', 'Infected (confirmed)')
#  ('Korea, South', 'Recovered') ('Kosovo', 'Deceased')
#  ('Kosovo', 'Infected (confirmed)') ('Kosovo', 'Recovered')
#  ('Kuwait', 'Deceased') ('Kuwait', 'Infected (confirmed)')
#  ('Kuwait', 'Recovered') ('Kyrgyzstan', 'Deceased')
#  ('Kyrgyzstan', 'Infected (confirmed)') ('Kyrgyzstan', 'Recovered')
#  ('Latvia', 'Deceased') ('Latvia', 'Infected (confirmed)')
#  ('Latvia', 'Recovered') ('Lebanon', 'Deceased')
#  ('Lebanon', 'Infected (confirmed)') ('Lebanon', 'Recovered')
#  ('Liberia', 'Deceased') ('Liberia', 'Infected (confirmed)')
#  ('Liberia', 'Recovered') ('Liechtenstein', 'Deceased')
#  ('Liechtenstein', 'Infected (confirmed)') ('Liechtenstein', 'Recovered')
#  ('Lithuania', 'Deceased') ('Lithuania', 'Infected (confirmed)')
#  ('Lithuania', 'Recovered') ('Luxembourg', 'Deceased')
#  ('Luxembourg', 'Infected (confirmed)') ('Luxembourg', 'Recovered')
#  ('Malaysia', 'Deceased') ('Malaysia', 'Infected (confirmed)')
#  ('Malaysia', 'Recovered') ('Maldives', 'Deceased')
#  ('Maldives', 'Infected (confirmed)') ('Maldives', 'Recovered')
#  ('Malta', 'Deceased') ('Malta', 'Infected (confirmed)')
#  ('Malta', 'Recovered') ('Martinique', 'Deceased')
#  ('Martinique', 'Infected (confirmed)') ('Martinique', 'Recovered')
#  ('Mauritania', 'Deceased') ('Mauritania', 'Infected (confirmed)')
#  ('Mauritania', 'Recovered') ('Mauritius', 'Deceased')
#  ('Mauritius', 'Infected (confirmed)') ('Mauritius', 'Recovered')
#  ('Mexico', 'Deceased') ('Mexico', 'Infected (confirmed)')
#  ('Mexico', 'Recovered') ('Moldova', 'Deceased')
#  ('Moldova', 'Infected (confirmed)') ('Moldova', 'Recovered')
#  ('Monaco', 'Deceased') ('Monaco', 'Infected (confirmed)')
#  ('Monaco', 'Recovered') ('Mongolia', 'Deceased')
#  ('Mongolia', 'Infected (confirmed)') ('Mongolia', 'Recovered')
#  ('Montenegro', 'Deceased') ('Montenegro', 'Infected (confirmed)')
#  ('Montenegro', 'Recovered') ('Morocco', 'Deceased')
#  ('Morocco', 'Infected (confirmed)') ('Morocco', 'Recovered')
#  ('Namibia', 'Deceased') ('Namibia', 'Infected (confirmed)')
#  ('Namibia', 'Recovered') ('Nepal', 'Deceased')
#  ('Nepal', 'Infected (confirmed)') ('Nepal', 'Recovered')
#  ('Netherlands', 'Deceased') ('Netherlands', 'Infected (confirmed)')
#  ('Netherlands', 'Recovered') ('New Zealand', 'Deceased')
#  ('New Zealand', 'Infected (confirmed)') ('New Zealand', 'Recovered')
#  ('Nicaragua', 'Deceased') ('Nicaragua', 'Infected (confirmed)')
#  ('Nicaragua', 'Recovered') ('Nigeria', 'Deceased')
#  ('Nigeria', 'Infected (confirmed)') ('Nigeria', 'Recovered')
#  ('North Macedonia', 'Deceased')
#  ('North Macedonia', 'Infected (confirmed)')
#  ('North Macedonia', 'Recovered') ('Norway', 'Deceased')
#  ('Norway', 'Infected (confirmed)') ('Norway', 'Recovered')
#  ('Oman', 'Deceased') ('Oman', 'Infected (confirmed)')
#  ('Oman', 'Recovered') ('Pakistan', 'Deceased')
#  ('Pakistan', 'Infected (confirmed)') ('Pakistan', 'Recovered')
#  ('Panama', 'Deceased') ('Panama', 'Infected (confirmed)')
#  ('Panama', 'Recovered') ('Paraguay', 'Deceased')
#  ('Paraguay', 'Infected (confirmed)') ('Paraguay', 'Recovered')
#  ('Peru', 'Deceased') ('Peru', 'Infected (confirmed)')
#  ('Peru', 'Recovered') ('Philippines', 'Deceased')
#  ('Philippines', 'Infected (confirmed)') ('Philippines', 'Recovered')
#  ('Poland', 'Deceased') ('Poland', 'Infected (confirmed)')
#  ('Poland', 'Recovered') ('Portugal', 'Deceased')
#  ('Portugal', 'Infected (confirmed)') ('Portugal', 'Recovered')
#  ('Qatar', 'Deceased') ('Qatar', 'Infected (confirmed)')
#  ('Qatar', 'Recovered') ('Romania', 'Deceased')
#  ('Romania', 'Infected (confirmed)') ('Romania', 'Recovered')
#  ('Russia', 'Deceased') ('Russia', 'Infected (confirmed)')
#  ('Russia', 'Recovered') ('Rwanda', 'Deceased')
#  ('Rwanda', 'Infected (confirmed)') ('Rwanda', 'Recovered')
#  ('Saint Lucia', 'Deceased') ('Saint Lucia', 'Infected (confirmed)')
#  ('Saint Lucia', 'Recovered')
#  ('Saint Vincent and the Grenadines', 'Deceased')
#  ('Saint Vincent and the Grenadines', 'Infected (confirmed)')
#  ('Saint Vincent and the Grenadines', 'Recovered')
#  ('San Marino', 'Deceased') ('San Marino', 'Infected (confirmed)')
#  ('San Marino', 'Recovered') ('Saudi Arabia', 'Deceased')
#  ('Saudi Arabia', 'Infected (confirmed)') ('Saudi Arabia', 'Recovered')
#  ('Senegal', 'Deceased') ('Senegal', 'Infected (confirmed)')
#  ('Senegal', 'Recovered') ('Serbia', 'Deceased')
#  ('Serbia', 'Infected (confirmed)') ('Serbia', 'Recovered')
#  ('Seychelles', 'Deceased') ('Seychelles', 'Infected (confirmed)')
#  ('Seychelles', 'Recovered') ('Singapore', 'Deceased')
#  ('Singapore', 'Infected (confirmed)') ('Singapore', 'Recovered')
#  ('Slovakia', 'Deceased') ('Slovakia', 'Infected (confirmed)')
#  ('Slovakia', 'Recovered') ('Slovenia', 'Deceased')
#  ('Slovenia', 'Infected (confirmed)') ('Slovenia', 'Recovered')
#  ('Somalia', 'Deceased') ('Somalia', 'Infected (confirmed)')
#  ('Somalia', 'Recovered') ('South Africa', 'Deceased')
#  ('South Africa', 'Infected (confirmed)') ('South Africa', 'Recovered')
#  ('Spain', 'Deceased') ('Spain', 'Infected (confirmed)')
#  ('Spain', 'Recovered') ('Sri Lanka', 'Deceased')
#  ('Sri Lanka', 'Infected (confirmed)') ('Sri Lanka', 'Recovered')
#  ('Sudan', 'Deceased') ('Sudan', 'Infected (confirmed)')
#  ('Sudan', 'Recovered') ('Suriname', 'Deceased')
#  ('Suriname', 'Infected (confirmed)') ('Suriname', 'Recovered')
#  ('Sweden', 'Deceased') ('Sweden', 'Infected (confirmed)')
#  ('Sweden', 'Recovered') ('Switzerland', 'Deceased')
#  ('Switzerland', 'Infected (confirmed)') ('Switzerland', 'Recovered')
#  ('Taiwan*', 'Deceased') ('Taiwan*', 'Infected (confirmed)')
#  ('Taiwan*', 'Recovered') ('Tanzania', 'Deceased')
#  ('Tanzania', 'Infected (confirmed)') ('Tanzania', 'Recovered')
#  ('Thailand', 'Deceased') ('Thailand', 'Infected (confirmed)')
#  ('Thailand', 'Recovered') ('Togo', 'Deceased')
#  ('Togo', 'Infected (confirmed)') ('Togo', 'Recovered')
#  ('Trinidad and Tobago', 'Deceased')
#  ('Trinidad and Tobago', 'Infected (confirmed)')
#  ('Trinidad and Tobago', 'Recovered') ('Tunisia', 'Deceased')
#  ('Tunisia', 'Infected (confirmed)') ('Tunisia', 'Recovered')
#  ('Turkey', 'Deceased') ('Turkey', 'Infected (confirmed)')
#  ('Turkey', 'Recovered') ('US', 'Deceased') ('US', 'Infected (confirmed)')
#  ('US', 'Recovered') ('Ukraine', 'Deceased')
#  ('Ukraine', 'Infected (confirmed)') ('Ukraine', 'Recovered')
#  ('United Arab Emirates', 'Deceased')
#  ('United Arab Emirates', 'Infected (confirmed)')
#  ('United Arab Emirates', 'Recovered') ('United Kingdom', 'Deceased')
#  ('United Kingdom', 'Infected (confirmed)')
#  ('United Kingdom', 'Recovered') ('Uruguay', 'Deceased')
#  ('Uruguay', 'Infected (confirmed)') ('Uruguay', 'Recovered')
#  ('Uzbekistan', 'Deceased') ('Uzbekistan', 'Infected (confirmed)')
#  ('Uzbekistan', 'Recovered') ('Venezuela', 'Deceased')
#  ('Venezuela', 'Infected (confirmed)') ('Venezuela', 'Recovered')
#  ('Vietnam', 'Deceased') ('Vietnam', 'Infected (confirmed)')
#  ('Vietnam', 'Recovered') ('Zambia', 'Deceased')
#  ('Zambia', 'Infected (confirmed)') ('Zambia', 'Recovered')]
# ['2020-01-22T00:00:00.000000000' '2020-01-23T00:00:00.000000000'
#  '2020-01-24T00:00:00.000000000' '2020-01-25T00:00:00.000000000'
#  '2020-01-26T00:00:00.000000000' '2020-01-27T00:00:00.000000000'
#  '2020-01-28T00:00:00.000000000' '2020-01-29T00:00:00.000000000'
#  '2020-01-30T00:00:00.000000000' '2020-01-31T00:00:00.000000000'
#  '2020-02-01T00:00:00.000000000' '2020-02-02T00:00:00.000000000'
#  '2020-02-03T00:00:00.000000000' '2020-02-04T00:00:00.000000000'
#  '2020-02-05T00:00:00.000000000' '2020-02-06T00:00:00.000000000'
#  '2020-02-07T00:00:00.000000000' '2020-02-08T00:00:00.000000000'
#  '2020-02-09T00:00:00.000000000' '2020-02-10T00:00:00.000000000'
#  '2020-02-11T00:00:00.000000000' '2020-02-12T00:00:00.000000000'
#  '2020-02-13T00:00:00.000000000' '2020-02-14T00:00:00.000000000'
#  '2020-02-15T00:00:00.000000000' '2020-02-16T00:00:00.000000000'
#  '2020-02-17T00:00:00.000000000' '2020-02-18T00:00:00.000000000'
#  '2020-02-19T00:00:00.000000000' '2020-02-20T00:00:00.000000000'
#  '2020-02-21T00:00:00.000000000' '2020-02-22T00:00:00.000000000'
#  '2020-02-23T00:00:00.000000000' '2020-02-24T00:00:00.000000000'
#  '2020-02-25T00:00:00.000000000' '2020-02-26T00:00:00.000000000'
#  '2020-02-27T00:00:00.000000000' '2020-02-28T00:00:00.000000000'
#  '2020-02-29T00:00:00.000000000' '2020-03-01T00:00:00.000000000'
#  '2020-03-02T00:00:00.000000000' '2020-03-03T00:00:00.000000000'
#  '2020-03-04T00:00:00.000000000' '2020-03-05T00:00:00.000000000'
#  '2020-03-06T00:00:00.000000000' '2020-03-07T00:00:00.000000000'
#  '2020-03-08T00:00:00.000000000' '2020-03-09T00:00:00.000000000'
#  '2020-03-10T00:00:00.000000000' '2020-03-11T00:00:00.000000000'
#  '2020-03-12T00:00:00.000000000' '2020-03-13T00:00:00.000000000'
#  '2020-03-14T00:00:00.000000000' '2020-03-15T00:00:00.000000000'
#  '2020-03-16T00:00:00.000000000' '2020-03-17T00:00:00.000000000'
#  '2020-03-18T00:00:00.000000000' '2020-03-19T00:00:00.000000000']
